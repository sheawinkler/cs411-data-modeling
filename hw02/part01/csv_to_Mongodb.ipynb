# %%
#Imports
import json
import pandas as pd
from tqdm import tqdm as loader
import numpy as np
import pymongo
from pymongo import MongoClient
import csv
import sys, getopt, pprint
print(sys.getrecursionlimit())
sys.setrecursionlimit(300000000)
print(sys.getrecursionlimit())
# Out:
# 300000000
# 300000000

# %%
# !pip3 install tqdm
# !pip install pymongo
# Out:
# Requirement already satisfied: tqdm in c:\python37\lib\site-packages (4.50.0)
# WARNING: You are using pip version 19.2.3, however version 20.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: pymongo in c:\programdata\anaconda3\lib\site-packages (3.11.0)

# %%
myclient = pymongo.MongoClient('localhost', 27017)
database = myclient['Assignment2Part01']

# %%
#Helper functions
def csv_to_json(filename,col_names):
    df = pd.read_csv(filename ,encoding = 'ISO-8859-1',names=col_names, header=None)
    return df
def filter_comments(post_id):
    try:
        filtered_comments = comments.loc[comments['post_ID'] == post_id]
        filtered_comments = filtered_comments.filter(items=['comment_ID', 'comment_content', 'vote', 'comment_author','created_date'])
        return list(filtered_comments.to_dict('records'))
    except:
        return list()
def filter_inlinks(post_id):
    try:
        filtered_inlinks = inlinks.loc[inlinks['post_ID'] == post_id]
        filtered_inlinks = filtered_inlinks.filter(items=['inlink_ID', 'title', 'author', 'date', 'URL'])
        return list(filtered_inlinks.to_dict('records'))
    except:
        return list()
def df_to_dict(dataframe):
    return dataframe.to_dict('records')
def create_collection(df,collectionName):
    collection = database[collectionName]
    return collection.insert_many(df_to_dict(df))

# %%
#Column 
authors_col = ['author_ID','author_name', 'MEIBI','MEIBIX','avg_words_perpost','avg_words_perpost_nostopwords']
comments_col = ['comment_ID','post_ID','comment_content','comment_author','created_date','vote']
inlinks_col = ['inlink_ID','post_ID','title','author','date','URL']
blogpost_col = ['post_ID','title','author_Name','author_id','num_comments','post_content','URL','date','num_retrieved_inlinks','num_retrieved_comments','post_length','post_length_no_stopwords', 'avd_word_length','avg_word_length_no_stopwords','MEIBI','MEBIX']

#Read
authors = csv_to_json('authors.csv', authors_col)
posts = csv_to_json('posts.csv', blogpost_col)
comments = csv_to_json('comments.csv', comments_col)
inlinks = csv_to_json('inlinks.csv', inlinks_col)

# %%
posts = posts.drop('num_comments', axis =1)
posts
# Out:
#        post_ID                                              title  \
# 0            1  We Just Tested Twitter&#8217;s @anywhere Platf...
# 1            2  Facebook To Launch &#8216;Relationships&#8217;...
# 2            3  NYTimes Request Correction/Removal Of Our Post...
# 3            4  Google Shows How HTML5 Can Run Quake In The Br...
# 4            5               The iPad: Apple&#8217;s Trojan Horse
# ...        ...                                                ...
# 19459    19460                             Google Reviews Profile
# 19460    19461                                   BackPack Profile
# 19461    19462                                     Plazes Profile
# 19462    19463                                 FeedLounge Profile
# 19463    19464                            Technorati Beta Profile
#
#              author_Name  author_id  \
# 0          Jason Kincaid          1
# 1          Jason Kincaid          1
# 2      Michael Arrington          2
# 3        Erick Schonfeld          3
# 4             John Biggs          4
# ...                  ...        ...
# 19459  Michael Arrington          2
# 19460  Michael Arrington          2
# 19461  Michael Arrington          2
# 19462  Michael Arrington          2
# 19463  Michael Arrington          2
#
#                                             post_content  \
# 0      During his keynote at SXSW last month, Twitter...
# 1      Later this month Facebook is holding its f8 co...
# 2      A NYTimes communications person emailed to ask...
# 3      A lot of attention lately has been put on the ...
# 4      Something struck me about Apple&#8217;s handli...
# ...                                                  ...
# 19459  Company: Google (Reviews)What is it?There&#821...
# 19460  Company: BackPackWhat is it?BackPack launched ...
# 19461  Company: PlazesWhat is it?Plazes made an annou...
# 19462  Company: FeedLoungeWhat is it?The FeedLounge w...
# 19463  Company: Technorati (Public Beta Redesign)What...
#
#                                                      URL        date  \
# 0      http://techcrunch.com/2010/04/01/we-just-teste...  2010-04-01
# 1      http://techcrunch.com/2010/04/01/facebook-to-l...  2010-04-01
# 2      http://techcrunch.com/2010/04/01/nytimes-reque...  2010-04-01
# 3      http://techcrunch.com/2010/04/01/google-html5-...  2010-04-01
# 4      http://www.crunchgear.com/2010/04/01/the-ipad-...  2010-04-01
# ...                                                  ...         ...
# 19459   http://techcrunch.com/2005/06/12/google-reviews/  2005-06-12
# 19460  http://techcrunch.com/2005/06/12/backpack-show...  2005-06-12
# 19461  http://techcrunch.com/2005/06/11/plazes-gets-t...  2005-06-11
# 19462  http://techcrunch.com/2005/06/11/get-in-line-t...  2005-06-11
# 19463  http://techcrunch.com/2005/06/11/technorati-ne...  2005-06-11
#
#        num_retrieved_inlinks  num_retrieved_comments  post_length  \
# 0                          0                      14          314
# 1                          0                      30          717
# 2                          4                      38          249
# 3                         10                      26          256
# 4                          1                      49          503
# ...                      ...                     ...          ...
# 19459                      0                       3          209
# 19460                      1                       6          572
# 19461                     10                      12          292
# 19462                      0                       9          211
# 19463                     18                      22          265
#
#        post_length_no_stopwords  avd_word_length  \
# 0                           223         4.130293
# 1                           488         4.138177
# 2                           168         3.572614
# 3                           172         3.628571
# 4                           348         3.773279
# ...                         ...              ...
# 19459                       141         3.737864
# 19460                       412         4.035842
# 19461                       217         4.313380
# 19462                       159         4.691176
# 19463                       195         4.944223
#
#        avg_word_length_no_stopwords       MEIBI  MEBIX
# 0                          5.686099     0.00000    0.0
# 1                          5.952869     0.00000    0.0
# 2                          5.125000   624.00000    0.0
# 3                          5.168605  1080.00000    0.0
# 4                          5.356322   200.00000    0.0
# ...                             ...         ...    ...
# 19459                      5.460993     0.00000    0.0
# 19460                      5.466019     0.01595    0.0
# 19461                      5.645161     0.29613    0.0
# 19462                      6.018868     0.00000    0.0
# 19463                      6.364103     0.94305    0.0
#
# [19464 rows x 15 columns]

# %%
#Get shape
print("Comments shape: {}".format(comments.shape))
print("Authors shape: {}".format(authors.shape))
print("Posts shape: {}".format(posts.shape))
print("Inlinks shape: {}".format(inlinks.shape))
# Out:
# Comments shape: (746561, 6)
# Authors shape: (107, 6)
# Posts shape: (19464, 15)
# Inlinks shape: (193808, 6)

# %%
comments
# Out:
#         comment_ID  post_ID  \
# 0                1        1
# 1                2        1
# 2                3        1
# 3                4        1
# 4                5        1
# ...            ...      ...
# 746556      746557     5765
# 746557      746558     5765
# 746558      746559     5765
# 746559      746560     5765
# 746560      746561     5765
#
#                                           comment_content  \
# 0                                    Seemed to work fine.
# 1       I tried this the first second you published it...
# 2       A lot of twitter apps (including mine) can mak...
# 3              Worked a minute ago, now it&#8217;s pulled
# 4       Yep. At 10:33pm pst it is down. I get an &#822...
# ...                                                   ...
# 746556  This sounds like a non-story.  One URL shorten...
# 746557  This is a non-story.  He knew about it and men...
# 746558  Man I feel kind of dumb. I didn&#8217;t even n...
# 746559  I don&#8217;t think its that big a deal and mo...
# 746560  actually i am happy with dig until this time ,...
#
#                       comment_author created_date  vote
# 0                            BJ Cook   2010-04-01     1
# 1                       Blitz Surfer   2010-04-01     1
# 2                     Nischal Shetty   2010-04-01     1
# 3                        Jonah Grant   2010-04-01     1
# 4                      Joshua Guffey   2010-04-01     1
# ...                              ...          ...   ...
# 746556                 Sanjay Sharma   2009-07-20     1
# 746557                           Amy   2009-07-20     1
# 746558                    Wallpapers   2009-07-20     1
# 746559                  Daniel Licht   2009-07-20     1
# 746560  Blogging Tips and make money   2009-07-22     1
#
# [746561 rows x 6 columns]

# %%
inlinks.columns
# Out:
# Index(['inlink_ID', 'post_ID', 'title', 'author', 'date', 'URL'], dtype='object')

# %%
post_id = 1 
filtered_comments = comments.loc[comments['post_ID'] == post_id]
filtered_comments = filtered_comments.filter(items=['comment_ID', 'comment_content', 'vote', 'created_date'])
json_ = filtered_comments.to_dict('records')

# %%
print(json_)
# Out:
# [{'comment_ID': 1, 'comment_content': 'Seemed to work fine.', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 2, 'comment_content': 'I tried this the first second you published it,it didn&#8217;t show the @anywhere, it said via Egg Boiling!', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 3, 'comment_content': 'A lot of twitter apps (including mine) can make use of hovercard to display user info. I would use it as soon as it becomes available!', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 4, 'comment_content': 'Worked a minute ago, now it&#8217;s pulled', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 5, 'comment_content': 'Yep. At 10:33pm pst it is down. I get an &#8220;index of&#8221; page. 20 minutes is a pretty good response time on their part. Only wish I had been faster. Thanks for the screenshots!', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 6, 'comment_content': 'Now it&#8217;s down!I love &#8220;view source&#8221; option on browser', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 7, 'comment_content': 'So basically @anywhere is just an Oauth login system, just like my facebook-connect or Google Friends Connect? What&#8217;s the added value?First with OpenID and Oauth people are told they only need 1 login to get everywhere. Now it seems I have to decide wheter to use my google, twitter or facebook account to do this&#8230;. I still miss something', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 8, 'comment_content': 'second, this looks exactly like facebook connect, the only cool thing is the rollover, but even that isn&#8217;t that cool.', 'vote': 1, 'created_date': '2010-04-02'}, {'comment_ID': 9, 'comment_content': 'Both brings login with their credentials, and post back to the mothership (Facebook or Twitter). Anything else though, because it sounds more phenomenal than that when announced.', 'vote': 1, 'created_date': '2010-04-02'}, {'comment_ID': 10, 'comment_content': 'well it&#8217;s a great feature.I am waiting for this twitter hovercard to be released officially.', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 11, 'comment_content': 'Is eggboiling.com a joke?', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 12, 'comment_content': 'Missed it', 'vote': 1, 'created_date': '2010-04-01'}, {'comment_ID': 13, 'comment_content': 'This doesn&#8217;t appear to have any functionality beyond what&#8217;s available currently through twitter&#8217;s oauth API. The exception is the hover card, although this could certainly be built with the current API and a little javascript.While this is certainly to do with @anywhere it makes me wonder how twitter will handle third party competition with this service &#8211; will they add terms to the API to stop people competing, or will they remove or limit certain methods. Either way, it&#8217;s a worry.', 'vote': 1, 'created_date': '2010-04-02'}, {'comment_ID': 14, 'comment_content': 'No kidding,  This is worst &#8230;.  still long way to go.', 'vote': 1, 'created_date': '2010-04-02'}]

# %%
posts["comments"] = np.nan
posts["comments"] = posts["comments"].astype('object')
posts["inlinks"] = np.nan
posts["inlinks"] = posts["inlinks"].astype('object')

# %%
posts.head()
# Out:
#    post_ID                                              title  \
# 0        1  We Just Tested Twitter&#8217;s @anywhere Platf...
# 1        2  Facebook To Launch &#8216;Relationships&#8217;...
# 2        3  NYTimes Request Correction/Removal Of Our Post...
# 3        4  Google Shows How HTML5 Can Run Quake In The Br...
# 4        5               The iPad: Apple&#8217;s Trojan Horse
#
#          author_Name  author_id  \
# 0      Jason Kincaid          1
# 1      Jason Kincaid          1
# 2  Michael Arrington          2
# 3    Erick Schonfeld          3
# 4         John Biggs          4
#
#                                         post_content  \
# 0  During his keynote at SXSW last month, Twitter...
# 1  Later this month Facebook is holding its f8 co...
# 2  A NYTimes communications person emailed to ask...
# 3  A lot of attention lately has been put on the ...
# 4  Something struck me about Apple&#8217;s handli...
#
#                                                  URL        date  \
# 0  http://techcrunch.com/2010/04/01/we-just-teste...  2010-04-01
# 1  http://techcrunch.com/2010/04/01/facebook-to-l...  2010-04-01
# 2  http://techcrunch.com/2010/04/01/nytimes-reque...  2010-04-01
# 3  http://techcrunch.com/2010/04/01/google-html5-...  2010-04-01
# 4  http://www.crunchgear.com/2010/04/01/the-ipad-...  2010-04-01
#
#    num_retrieved_inlinks  num_retrieved_comments  post_length  \
# 0                      0                      14          314
# 1                      0                      30          717
# 2                      4                      38          249
# 3                     10                      26          256
# 4                      1                      49          503
#
#    post_length_no_stopwords  avd_word_length  avg_word_length_no_stopwords  \
# 0                       223         4.130293                      5.686099
# 1                       488         4.138177                      5.952869
# 2                       168         3.572614                      5.125000
# 3                       172         3.628571                      5.168605
# 4                       348         3.773279                      5.356322
#
#     MEIBI  MEBIX comments inlinks
# 0     0.0    0.0      NaN     NaN
# 1     0.0    0.0      NaN     NaN
# 2   624.0    0.0      NaN     NaN
# 3  1080.0    0.0      NaN     NaN
# 4   200.0    0.0      NaN     NaN

# %%
for idx, post in enumerate(loader(posts.iterrows())):
    post_id = post[1]['post_ID']
    posts.at[idx, 'comments'] =  filter_comments(post_id)
    posts.at[idx, 'inlinks'] = filter_inlinks(post_id)
# Out:
# 19464it [01:18, 247.89it/s]

# %%
posts
# Out:
#        post_ID                                              title  \
# 0            1  We Just Tested Twitter&#8217;s @anywhere Platf...
# 1            2  Facebook To Launch &#8216;Relationships&#8217;...
# 2            3  NYTimes Request Correction/Removal Of Our Post...
# 3            4  Google Shows How HTML5 Can Run Quake In The Br...
# 4            5               The iPad: Apple&#8217;s Trojan Horse
# ...        ...                                                ...
# 19459    19460                             Google Reviews Profile
# 19460    19461                                   BackPack Profile
# 19461    19462                                     Plazes Profile
# 19462    19463                                 FeedLounge Profile
# 19463    19464                            Technorati Beta Profile
#
#              author_Name  author_id  \
# 0          Jason Kincaid          1
# 1          Jason Kincaid          1
# 2      Michael Arrington          2
# 3        Erick Schonfeld          3
# 4             John Biggs          4
# ...                  ...        ...
# 19459  Michael Arrington          2
# 19460  Michael Arrington          2
# 19461  Michael Arrington          2
# 19462  Michael Arrington          2
# 19463  Michael Arrington          2
#
#                                             post_content  \
# 0      During his keynote at SXSW last month, Twitter...
# 1      Later this month Facebook is holding its f8 co...
# 2      A NYTimes communications person emailed to ask...
# 3      A lot of attention lately has been put on the ...
# 4      Something struck me about Apple&#8217;s handli...
# ...                                                  ...
# 19459  Company: Google (Reviews)What is it?There&#821...
# 19460  Company: BackPackWhat is it?BackPack launched ...
# 19461  Company: PlazesWhat is it?Plazes made an annou...
# 19462  Company: FeedLoungeWhat is it?The FeedLounge w...
# 19463  Company: Technorati (Public Beta Redesign)What...
#
#                                                      URL        date  \
# 0      http://techcrunch.com/2010/04/01/we-just-teste...  2010-04-01
# 1      http://techcrunch.com/2010/04/01/facebook-to-l...  2010-04-01
# 2      http://techcrunch.com/2010/04/01/nytimes-reque...  2010-04-01
# 3      http://techcrunch.com/2010/04/01/google-html5-...  2010-04-01
# 4      http://www.crunchgear.com/2010/04/01/the-ipad-...  2010-04-01
# ...                                                  ...         ...
# 19459   http://techcrunch.com/2005/06/12/google-reviews/  2005-06-12
# 19460  http://techcrunch.com/2005/06/12/backpack-show...  2005-06-12
# 19461  http://techcrunch.com/2005/06/11/plazes-gets-t...  2005-06-11
# 19462  http://techcrunch.com/2005/06/11/get-in-line-t...  2005-06-11
# 19463  http://techcrunch.com/2005/06/11/technorati-ne...  2005-06-11
#
#        num_retrieved_inlinks  num_retrieved_comments  post_length  \
# 0                          0                      14          314
# 1                          0                      30          717
# 2                          4                      38          249
# 3                         10                      26          256
# 4                          1                      49          503
# ...                      ...                     ...          ...
# 19459                      0                       3          209
# 19460                      1                       6          572
# 19461                     10                      12          292
# 19462                      0                       9          211
# 19463                     18                      22          265
#
#        post_length_no_stopwords  avd_word_length  \
# 0                           223         4.130293
# 1                           488         4.138177
# 2                           168         3.572614
# 3                           172         3.628571
# 4                           348         3.773279
# ...                         ...              ...
# 19459                       141         3.737864
# 19460                       412         4.035842
# 19461                       217         4.313380
# 19462                       159         4.691176
# 19463                       195         4.944223
#
#        avg_word_length_no_stopwords       MEIBI  MEBIX  \
# 0                          5.686099     0.00000    0.0
# 1                          5.952869     0.00000    0.0
# 2                          5.125000   624.00000    0.0
# 3                          5.168605  1080.00000    0.0
# 4                          5.356322   200.00000    0.0
# ...                             ...         ...    ...
# 19459                      5.460993     0.00000    0.0
# 19460                      5.466019     0.01595    0.0
# 19461                      5.645161     0.29613    0.0
# 19462                      6.018868     0.00000    0.0
# 19463                      6.364103     0.94305    0.0
#
#                                                 comments  \
# 0      [{'comment_ID': 1, 'comment_content': 'Seemed ...
# 1      [{'comment_ID': 15, 'comment_content': 'Is apr...
# 2      [{'comment_ID': 258854, 'comment_content': 'lm...
# 3      [{'comment_ID': 511943, 'comment_content': 'ty...
# 4      [{'comment_ID': 588817, 'comment_content': 'yo...
# ...                                                  ...
# 19459  [{'comment_ID': 570372, 'comment_content': 'Re...
# 19460  [{'comment_ID': 570375, 'comment_content': 'Bu...
# 19461  [{'comment_ID': 570381, 'comment_content': 'Yo...
# 19462  [{'comment_ID': 570393, 'comment_content': 'Yo...
# 19463  [{'comment_ID': 570402, 'comment_content': 'Te...
#
#                                                  inlinks
# 0                                                     []
# 1                                                     []
# 2      [{'inlink_ID': 513699, 'title': 'Moving into t...
# 3      [{'inlink_ID': 513689, 'title': 'Quake II func...
# 4      [{'inlink_ID': 513688, 'title': 'Budget Nomad:...
# ...                                                  ...
# 19459                                                 []
# 19460  [{'inlink_ID': 319923, 'title': 'talking tech ...
# 19461  [{'inlink_ID': 319913, 'title': 'the time, the...
# 19462                                                 []
# 19463  [{'inlink_ID': 319895, 'title': 'Popular Blogs...
#
# [19464 rows x 17 columns]

# %%
collection = database['posts']
collection.insert_many(posts.to_dict('records'))
collection = database['authors']
collection.insert_many(authors.to_dict('records'))
